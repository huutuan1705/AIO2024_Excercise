# %%
# !gdown --id 1SqSn_8rxkk-Qvu4JLMcN_3ZFGDNa6P_V

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F

from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
random_state = 59
np.random.seed(random_state)
torch.manual_seed(random_state)
if torch.cuda.is_available():
    torch.cuda.manual_seed(random_state)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
data_path = "NonLinear_data.npy"
data = np.load(data_path, allow_pickle=True).item()
X, y = data['X'], data['labels']

print(X.shape, y.shape)
# Out:
# (300, 2) (300,)

# %%
val_size = 0.2
test_size = 0.125
random_state = 2
is_shuffle = True

X_train, X_val, y_train, y_val = train_test_split(
    X, y,
    test_size=val_size,
    random_state=random_state,
    shuffle=is_shuffle
)

X_train, X_test, y_train, y_test = train_test_split(
    X_train, y_train,
    test_size=test_size,
    random_state=random_state,
    shuffle=is_shuffle
)

# %%
normalizer = StandardScaler()
X_train = normalizer.fit_transform(X_train)
X_val = normalizer.transform(X_val)
X_test = normalizer.transform(X_test)

X_train = torch.tensor(X_train, dtype=torch.float32)
X_val = torch.tensor(X_val, dtype=torch.float32)
X_test = torch.tensor(X_test, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.long)
y_val = torch.tensor(y_val, dtype=torch.long)
y_test = torch.tensor(y_test, dtype=torch.long)

# %%
class CustomDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y
        
    def __len__(self):
        return len(self.y)
    
    def __getitem__(self, index):
        return self.X[index], self.y[index]

# %%
batch_size = 32
train_dataset = CustomDataset(X_train, y_train)
val_dataset = CustomDataset(X_val, y_val)
test_dataset = CustomDataset(X_test, y_test)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
class MLP(nn.Module):
    def __init__(self, input_dims, hidden_dims, output_dim):
        super(MLP, self).__init__()
        self.linear1 = nn.Linear(input_dims, hidden_dims)
        self.output = nn.Linear(hidden_dims, output_dim)
        self.relu = nn.ReLU()
        self.sigmoid = nn.Sigmoid()
        self.tanh = nn.Tanh()
        
    def forward(self, x):
        x = self.linear1(x)
        x = self.tanh(x)
        out = self.output(x)
        
        return out.squeeze(1)

# %%
# class MLP(nn.Module):
#     def __init__(self, input_dims, hidden_dims, output_dim):
#         super(MLP, self).__init__()
#         self.output = nn.Linear(input_dims, output_dim)
        
#     def forward(self, x):
#         x = self.output(x)
#         out = F.softmax(x)
        
#         return out.squeeze(1)

# %%
input_dims = X_train.shape[1]
output_dims = torch.unique(y_train).shape[0]
hidden_dims = 512

model = MLP(input_dims=input_dims, hidden_dims=hidden_dims, output_dim=output_dims).to(device)

# %%
lr = 1e-1
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=lr)

# %%
def compute_accuracy(y_hat, y_true):
    _, y_hat = torch.max(y_hat, dim=1)
    correct = (y_hat == y_true).sum().item()
    accuracy = correct / len(y_true)
    
    return accuracy

# %%
epochs = 100
train_losses = []
val_losses = []
train_accs = []
val_accs = []

for epoch in range(epochs):
    train_loss = 0.0
    train_target = []
    val_target = []
    train_predict = []
    val_predict = []
    model.train()
    
    for X_samples, y_samples in train_loader:
        X_samples = X_samples.to(device)
        y_samples = y_samples.to(device)
        
        optimizer.zero_grad()
        outputs = model(X_samples)
        loss = criterion(outputs, y_samples)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
        
        train_predict.append(outputs.detach().cpu())
        train_target.append(y_samples.cpu())
        
    train_loss /= len(train_loader)
    train_losses.append(train_loss)
    
    train_predict = torch.cat(train_predict)
    train_target = torch.cat(train_target)
    train_acc = compute_accuracy(train_predict, train_target)
    train_accs.append(train_acc)
    
    model.eval()
    val_loss = 0.0
    
    with torch.no_grad():
        for X_samples, y_samples in val_loader:
            X_samples = X_samples.to(device)
            y_samples = y_samples.to(device)
            outputs = model(X_samples)
            
            loss = criterion(outputs, y_samples)
            
            val_loss += loss.item()
            
            val_predict.append(outputs.cpu())
            val_target.append(y_samples.cpu())
            
    val_loss /= len(val_loader)
    val_losses.append(val_loss)
    
    val_predict = torch.cat(val_predict)
    val_target = torch.cat(val_target)
    val_acc = compute_accuracy(val_predict, val_target)
    val_accs.append(val_acc)
    
    print(f'\nEPOCH {epoch + 1}:\tTraining loss: {train_loss:.3f} \tValidation loss: {val_loss:.3f}')
# Out:
# EPOCH 1:	Training loss: 0.864 	Validation loss: 1.139
#
# EPOCH 2:	Training loss: 0.908 	Validation loss: 1.059
#
# EPOCH 3:	Training loss: 0.881 	Validation loss: 0.867
#
# EPOCH 4:	Training loss: 0.755 	Validation loss: 0.813
#
# EPOCH 5:	Training loss: 0.822 	Validation loss: 0.867
#
# EPOCH 6:	Training loss: 0.744 	Validation loss: 0.807
#
# EPOCH 7:	Training loss: 0.731 	Validation loss: 0.758
#
# EPOCH 8:	Training loss: 0.715 	Validation loss: 0.782
#
# EPOCH 9:	Training loss: 0.681 	Validation loss: 0.831
#
# EPOCH 10:	Training loss: 0.741 	Validation loss: 0.917
#
# EPOCH 11:	Training loss: 0.790 	Validation loss: 0.690
#
# EPOCH 12:	Training loss: 0.744 	Validation loss: 0.830
#
# EPOCH 13:	Training loss: 0.642 	Validation loss: 0.684
#
# EPOCH 14:	Training loss: 0.600 	Validation loss: 0.722
#
# EPOCH 15:	Training loss: 0.606 	Validation loss: 0.762
#
# EPOCH 16:	Training loss: 0.724 	Validation loss: 0.982
#
# EPOCH 17:	Training loss: 0.700 	Validation loss: 0.704
#
# EPOCH 18:	Training loss: 0.637 	Validation loss: 0.735
#
# EPOCH 19:	Training loss: 0.544 	Validation loss: 1.161
#
# EPOCH 20:	Training loss: 0.752 	Validation loss: 0.903
#
# EPOCH 21:	Training loss: 0.632 	Validation loss: 0.614
#
# EPOCH 22:	Training loss: 0.563 	Validation loss: 1.035
#
# EPOCH 23:	Training loss: 0.660 	Validation loss: 0.658
#
# EPOCH 24:	Training loss: 0.479 	Validation loss: 0.587
#
# EPOCH 25:	Training loss: 0.508 	Validation loss: 0.718
#
# EPOCH 26:	Training loss: 0.522 	Validation loss: 0.836
#
# EPOCH 27:	Training loss: 0.532 	Validation loss: 0.609
#
# EPOCH 28:	Training loss: 0.477 	Validation loss: 0.641
#
# EPOCH 29:	Training loss: 0.475 	Validation loss: 0.555
#
# EPOCH 30:	Training loss: 0.448 	Validation loss: 0.477
#
# EPOCH 31:	Training loss: 0.457 	Validation loss: 0.618
#
# EPOCH 32:	Training loss: 0.465 	Validation loss: 0.479
#
# EPOCH 33:	Training loss: 0.418 	Validation loss: 0.456
#
# EPOCH 34:	Training loss: 0.381 	Validation loss: 0.497
#
# EPOCH 35:	Training loss: 0.445 	Validation loss: 0.449
#
# EPOCH 36:	Training loss: 0.393 	Validation loss: 0.496
#
# EPOCH 37:	Training loss: 0.385 	Validation loss: 0.569
#
# EPOCH 38:	Training loss: 0.444 	Validation loss: 0.456
#
# EPOCH 39:	Training loss: 0.374 	Validation loss: 0.489
#
# EPOCH 40:	Training loss: 0.403 	Validation loss: 0.411
#
# EPOCH 41:	Training loss: 0.350 	Validation loss: 0.415
#
# EPOCH 42:	Training loss: 0.346 	Validation loss: 0.489
#
# EPOCH 43:	Training loss: 0.385 	Validation loss: 0.437
#
# EPOCH 44:	Training loss: 0.334 	Validation loss: 0.418
#
# EPOCH 45:	Training loss: 0.349 	Validation loss: 0.485
#
# EPOCH 46:	Training loss: 0.312 	Validation loss: 0.416
#
# EPOCH 47:	Training loss: 0.307 	Validation loss: 0.439
#
# EPOCH 48:	Training loss: 0.347 	Validation loss: 0.387
#
# EPOCH 49:	Training loss: 0.310 	Validation loss: 0.410
#
# EPOCH 50:	Training loss: 0.330 	Validation loss: 0.350
#
# EPOCH 51:	Training loss: 0.327 	Validation loss: 0.396
#
# EPOCH 52:	Training loss: 0.309 	Validation loss: 0.356
#
# EPOCH 53:	Training loss: 0.312 	Validation loss: 0.342
#
# EPOCH 54:	Training loss: 0.277 	Validation loss: 0.351
#
# EPOCH 55:	Training loss: 0.296 	Validation loss: 0.345
#
# EPOCH 56:	Training loss: 0.303 	Validation loss: 0.367
#
# EPOCH 57:	Training loss: 0.283 	Validation loss: 0.391
#
# EPOCH 58:	Training loss: 0.278 	Validation loss: 0.438
#
# EPOCH 59:	Training loss: 0.273 	Validation loss: 0.334
#
# EPOCH 60:	Training loss: 0.271 	Validation loss: 0.340
#
# EPOCH 61:	Training loss: 0.267 	Validation loss: 0.346
#
# EPOCH 62:	Training loss: 0.256 	Validation loss: 0.329
#
# EPOCH 63:	Training loss: 0.262 	Validation loss: 0.336
#
# EPOCH 64:	Training loss: 0.249 	Validation loss: 0.323
#
# EPOCH 65:	Training loss: 0.245 	Validation loss: 0.303
#
# EPOCH 66:	Training loss: 0.241 	Validation loss: 0.285
#
# EPOCH 67:	Training loss: 0.234 	Validation loss: 0.294
#
# EPOCH 68:	Training loss: 0.243 	Validation loss: 0.306
#
# EPOCH 69:	Training loss: 0.248 	Validation loss: 0.281
#
# EPOCH 70:	Training loss: 0.227 	Validation loss: 0.302
#
# EPOCH 71:	Training loss: 0.233 	Validation loss: 0.317
#
# EPOCH 72:	Training loss: 0.221 	Validation loss: 0.292
#
# EPOCH 73:	Training loss: 0.236 	Validation loss: 0.314
#
# EPOCH 74:	Training loss: 0.224 	Validation loss: 0.321
#
# EPOCH 75:	Training loss: 0.232 	Validation loss: 0.284
#
# EPOCH 76:	Training loss: 0.201 	Validation loss: 0.281
#
# EPOCH 77:	Training loss: 0.216 	Validation loss: 0.279
#
# EPOCH 78:	Training loss: 0.210 	Validation loss: 0.271
#
# EPOCH 79:	Training loss: 0.210 	Validation loss: 0.277
#
# EPOCH 80:	Training loss: 0.211 	Validation loss: 0.258
#
# EPOCH 81:	Training loss: 0.201 	Validation loss: 0.271
#
# EPOCH 82:	Training loss: 0.218 	Validation loss: 0.261
#
# EPOCH 83:	Training loss: 0.196 	Validation loss: 0.276
#
# EPOCH 84:	Training loss: 0.196 	Validation loss: 0.264
#
# EPOCH 85:	Training loss: 0.197 	Validation loss: 0.266
#
# EPOCH 86:	Training loss: 0.192 	Validation loss: 0.259
#
# EPOCH 87:	Training loss: 0.191 	Validation loss: 0.281
#
# EPOCH 88:	Training loss: 0.186 	Validation loss: 0.255
#
# EPOCH 89:	Training loss: 0.186 	Validation loss: 0.271
#
# EPOCH 90:	Training loss: 0.180 	Validation loss: 0.263
#
# EPOCH 91:	Training loss: 0.186 	Validation loss: 0.251
#
# EPOCH 92:	Training loss: 0.194 	Validation loss: 0.268
#
# EPOCH 93:	Training loss: 0.192 	Validation loss: 0.245
#
# EPOCH 94:	Training loss: 0.174 	Validation loss: 0.242
#
# EPOCH 95:	Training loss: 0.170 	Validation loss: 0.255
#
# EPOCH 96:	Training loss: 0.171 	Validation loss: 0.237
#
# EPOCH 97:	Training loss: 0.177 	Validation loss: 0.243
#
# EPOCH 98:	Training loss: 0.173 	Validation loss: 0.250
#
# EPOCH 99:	Training loss: 0.167 	Validation loss: 0.241
#
# EPOCH 100:	Training loss: 0.163 	Validation loss: 0.237

# %%
fig, ax = plt.subplots(2, 2, figsize=(12, 10))
ax[0, 0].plot(train_losses, color='green')
ax[0, 0].set(xlabel='Epoch', ylabel='Loss')
ax[0, 0].set_title('Training Loss')

ax[0, 1].plot(val_losses, color='orange')
ax[0, 1].set(xlabel='Epoch', ylabel='Loss')
ax[0, 1].set_title('Validation Loss')

ax[1, 0].plot(train_accs, color='green')

ax[1, 0].set(xlabel='Epoch', ylabel='Accuracy')
ax[1, 0].set_title('Training Accuracy')
ax[1, 1].plot(val_accs, color='orange')
ax[1, 1].set(xlabel='Epoch', ylabel='Accuracy')
ax[1, 1].set_title('Validation Accuracy')
plt.show()

# %%
test_target = []
test_predict = []
model.eval()

with torch.no_grad():
    for X_samples, y_samples in test_loader:
        X_samples = X_samples.to(device)
        y_samples = y_samples.to(device)
        outputs = model(X_samples)
        test_predict.append(outputs.cpu())
        test_target.append(y_samples.cpu())
    test_predict = torch.cat(test_predict)
    test_target = torch.cat(test_target)
    test_acc = compute_accuracy(test_predict, test_target)
    print('Evaluation on test set:')
    print(f'Accuracy: {test_acc}')
# Out:
# Evaluation on test set:
# Accuracy: 0.9
